# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/X_datagen_allcomb_foreign_class_fixed_more_latest_normalised.npy")
X.shape
# Out:
# (180000, 1000)

# %%
y = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/y_datagen_allcomb_foreign_hotencoding_fixed_more_latest_normalised.npy")
y.shape
# Out:
# (180000, 5)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,shuffle = True, random_state = 34)

# %%
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, Flatten, Dense

# %%
class ResidualBlock(tf.keras.layers.Layer):
    def __init__(self, in_channels, out_channels, stride=1, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()

        # Layers
        self.conv1 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=stride, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.dropout = tf.keras.layers.Dropout(dropout_rate)

        self.shortcut = tf.keras.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = tf.keras.Sequential([
                tf.keras.layers.Conv1D(out_channels, kernel_size=1,
                                        strides=stride, use_bias=False),
                tf.keras.layers.BatchNormalization()
            ])

    def call(self, x):
        out = tf.nn.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.dropout(out)
        out += self.shortcut(x)
        out = tf.nn.relu(out)
        return out


class ResNet(tf.keras.Model):
    def __init__(self, hidden_sizes, num_blocks, input_dim=1000,
                 in_channels=64, n_classes=5, dropout_rate=0.2):
        super(ResNet, self).__init__()
        assert len(num_blocks) == len(hidden_sizes)
        self.input_dim = input_dim
        self.in_channels = in_channels
        self.n_classes = n_classes
        self.dropout_rate = dropout_rate
        
        self.conv1 = tf.keras.layers.Conv1D(in_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        
        # Flexible number of residual encoding layers
        layers = []
        strides = [1] + [2] * (len(hidden_sizes) - 1)
        for idx, hidden_size in enumerate(hidden_sizes):
            layers.append(self._make_layer(hidden_size, num_blocks[idx],
                                            stride=strides[idx]))
        self.encoder = tf.keras.Sequential(layers)

        self.global_pooling = tf.keras.layers.GlobalAveragePooling1D()
        self.z_dim = self._get_encoding_size()
        self.linear = tf.keras.layers.Dense(n_classes, activation='sigmoid')


    def encode(self, x):
        x = tf.nn.relu(self.bn1(self.conv1(x)))
        x = self.encoder(x)
        x = self.global_pooling(x)
        return x

    def call(self, x):
        z = self.encode(x)
        logits = self.linear(z)
        return logits


    def _make_layer(self, out_channels, num_blocks, stride=1):
        strides = [stride] + [1] * (num_blocks - 1)
        blocks = []
        for stride in strides:
            blocks.append(ResidualBlock(self.in_channels, out_channels,
                                            stride=stride, dropout_rate=self.dropout_rate))
            self.in_channels = out_channels
        return tf.keras.Sequential(blocks)

    def _get_encoding_size(self):
        """
        Returns the dimension of the encoded input.
        """
        temp = tf.random.normal((1, self.input_dim, 1))
        z = self.encode(temp)
        z_dim = z.shape[1]
        return z_dim

# %%
def create_model():
    layers = 3
    hidden_size = 50
    block_size = 2
    hidden_sizes = [hidden_size] * layers
    num_blocks = [block_size] * layers
    input_dim = 1000
    in_channels = 64
    model = ResNet(hidden_sizes, num_blocks, input_dim, in_channels, n_classes=1)
    model.compile(optimizer='adam', 
              loss=['binary_crossentropy'],
              metrics=['accuracy'])
    model.build(input_shape=(None, input_dim, 1))
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "res_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  320
#
#  batch_normalization (BatchN  multiple                 256
#  ormalization)
#
#  sequential_12 (Sequential)  (None, 250, 50)           164700
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dense (Dense)               multiple                  51
#
# =================================================================
# Total params: 165,327
# Trainable params: 163,699
# Non-trainable params: 1,628
# _________________________________________________________________

# %%
import pickle

# %%
history = model.fit(X_train.reshape(-1, 1000, 1),y_train[:,0],epochs = 30, validation_data = (X_test.reshape(-1,1000,1),y_test[:,0]))
filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/Resnet_individual_0.pkl'

pickle.dump(model, open(filepath, 'wb'))
# Out:
# Epoch 1/30
# 4219/4219 [==============================] - 176s 37ms/step - loss: 0.4166 - accuracy: 0.8141 - val_loss: 0.7983 - val_accuracy: 0.6596
# Epoch 2/30
# 4219/4219 [==============================] - 147s 35ms/step - loss: 0.3721 - accuracy: 0.8393 - val_loss: 0.7168 - val_accuracy: 0.7065
# Epoch 3/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.3521 - accuracy: 0.8514 - val_loss: 0.5013 - val_accuracy: 0.7927
# Epoch 4/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3426 - accuracy: 0.8565 - val_loss: 0.3329 - val_accuracy: 0.8681
# Epoch 5/30
# 4219/4219 [==============================] - 143s 34ms/step - loss: 0.3355 - accuracy: 0.8608 - val_loss: 0.3244 - val_accuracy: 0.8686
# Epoch 6/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3306 - accuracy: 0.8627 - val_loss: 0.3652 - val_accuracy: 0.8452
# Epoch 7/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.3263 - accuracy: 0.8653 - val_loss: 0.3708 - val_accuracy: 0.8337
# Epoch 8/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.3229 - accuracy: 0.8664 - val_loss: 0.3474 - val_accuracy: 0.8479
# Epoch 9/30
# 4219/4219 [==============================] - 138s 33ms/step - loss: 0.3186 - accuracy: 0.8689 - val_loss: 2.2489 - val_accuracy: 0.4733
# Epoch 10/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.3164 - accuracy: 0.8700 - val_loss: 0.3353 - val_accuracy: 0.8757
# Epoch 29/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.2739 - accuracy: 0.8886 - val_loss: 0.5108 - val_accuracy: 0.8139
# Epoch 30/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.2696 - accuracy: 0.8899 - val_loss: 0.3992 - val_accuracy: 0.8659

# %%
np.save('/content/drive/MyDrive/data sem thesis abhishek/normalised_data/Resnet_individual_history_0.npy',history.history)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = create_model()

# %%
history = model.fit(X_train.reshape(-1, 1000, 1),y_train[:,1],epochs = 30, validation_data = (X_test.reshape(-1,1000,1),y_test[:,1]))
filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/Resnet_individual_1.pkl'

pickle.dump(model, open(filepath, 'wb'))
# Out:
# Epoch 1/30
# 4219/4219 [==============================] - 153s 34ms/step - loss: 0.3650 - accuracy: 0.8492 - val_loss: 0.3035 - val_accuracy: 0.8821
# Epoch 2/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.2959 - accuracy: 0.8860 - val_loss: 0.4241 - val_accuracy: 0.7779
# Epoch 3/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.2751 - accuracy: 0.8967 - val_loss: 0.3620 - val_accuracy: 0.8745
# Epoch 4/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.2658 - accuracy: 0.9012 - val_loss: 0.2537 - val_accuracy: 0.9075
# Epoch 5/30
# 4219/4219 [==============================] - 143s 34ms/step - loss: 0.2598 - accuracy: 0.9046 - val_loss: 0.2787 - val_accuracy: 0.8881
# Epoch 6/30
# 4219/4219 [==============================] - 141s 34ms/step - loss: 0.2555 - accuracy: 0.9073 - val_loss: 0.2677 - val_accuracy: 0.9053
# Epoch 7/30
# 4219/4219 [==============================] - 143s 34ms/step - loss: 0.2518 - accuracy: 0.9082 - val_loss: 0.3011 - val_accuracy: 0.8690
# Epoch 8/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.2481 - accuracy: 0.9105 - val_loss: 0.2486 - val_accuracy: 0.9128
# Epoch 9/30
# 4219/4219 [==============================] - 143s 34ms/step - loss: 0.2456 - accuracy: 0.9120 - val_loss: 0.3016 - val_accuracy: 0.8895
# Epoch 10/30
# 4219/4219 [==============================] - 137s 33ms/step - loss: 0.2431 - accuracy: 0.9124 - val_loss: 0.2455 - val_accuracy: 0.9110
# Epoch 11/30
# 4219/4219 [==============================] - 138s 33ms/step - loss: 0.2416 - accuracy: 0.9126 - val_loss: 0.2499 - val_accuracy: 0.9114
# Epoch 12/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.2398 - accuracy: 0.9132 - val_loss: 0.2624 - val_accuracy: 0.9062
# Epoch 13/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.2374 - accuracy: 0.9148 - val_loss: 0.2547 - val_accuracy: 0.9054
