# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/X_datagen_allcomb_foreign_class_fixed_more_latest_normalised.npy")
X.shape
# Out:
# (180000, 1000)

# %%
y = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/y_datagen_allcomb_foreign_hotencoding_fixed_more_latest_normalised.npy")
y.shape
# Out:
# (180000, 5)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,shuffle = True, random_state = 34)

# %%
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, Flatten, Dense

# %%
class SEBlock(tf.keras.layers.Layer):
    def __init__(self, channels, reduction_ratio=16):
        super(SEBlock, self).__init__()
        self.channels = channels
        self.reduction_ratio = reduction_ratio
        self.avg_pool = tf.keras.layers.GlobalAveragePooling1D()
        self.fc1 = tf.keras.layers.Dense(channels // reduction_ratio, activation='relu')
        self.fc2 = tf.keras.layers.Dense(channels, activation='sigmoid')

    def call(self, x):
        x_se = self.avg_pool(x)
        x_se = self.fc1(x_se)
        x_se = self.fc2(x_se)
        x_se = tf.reshape(x_se, [-1, 1, self.channels])
        x = x * x_se
        return x

    
class ResidualBlock(tf.keras.layers.Layer):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()

        # Layers
        self.conv1 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=stride, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.se = SEBlock(out_channels)
        self.conv2 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn2 = tf.keras.layers.BatchNormalization()

        self.shortcut = tf.keras.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = tf.keras.Sequential([
                tf.keras.layers.Conv1D(out_channels, kernel_size=1,
                                        strides=stride, use_bias=False),
                tf.keras.layers.BatchNormalization()
            ])

    def call(self, x):
        out = tf.nn.relu(self.bn1(self.conv1(x)))
        out = self.se(out)
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = tf.nn.relu(out)
        return out


class ResNet(tf.keras.Model):
    def __init__(self, hidden_sizes, num_blocks, input_dim=1000,
                 in_channels=64, n_classes=5):
        super(ResNet, self).__init__()
        assert len(num_blocks) == len(hidden_sizes)
        self.input_dim = input_dim
        self.in_channels = in_channels
        self.n_classes = n_classes
        
        self.conv1 = tf.keras.layers.Conv1D(in_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        
        # Flexible number of residual encoding layers
        layers = []
        strides = [1] + [2] * (len(hidden_sizes) - 1)
        for idx, hidden_size in enumerate(hidden_sizes):
            layers.append(self._make_layer(hidden_size, num_blocks[idx],
                                            stride=strides[idx]))
        self.encoder = tf.keras.Sequential(layers)

        self.global_pooling = tf.keras.layers.GlobalAveragePooling1D()
        self.z_dim = self._get_encoding_size()
        self.linear = tf.keras.layers.Dense(n_classes, activation='sigmoid')


    def encode(self, x):
        x = tf.nn.relu(self.bn1(self.conv1(x)))
        x = self.encoder(x)
        x = self.global_pooling(x)
        return x

    def call(self, x):
        z = self.encode(x)
        logits = self.linear(z)
        return logits


    def _make_layer(self, out_channels, num_blocks, stride=1):
        strides = [stride] + [1] * (num_blocks - 1)
        blocks = []
        for stride in strides:
            blocks.append(ResidualBlock(self.in_channels, out_channels,
                                            stride=stride))
            blocks.append(SEBlock(out_channels))
            self.in_channels = out_channels
        return tf.keras.Sequential(blocks)


    def _get_encoding_size(self):
        """
        Returns the dimension of the encoded input.
        """
        temp = tf.random.normal((1, self.input_dim, 1))
        z = self.encode(temp)
        z_dim = z.shape[1]
        return z_dim

# %%
def create_model():
    layers = 3
    hidden_size = 50
    block_size = 2
    hidden_sizes = [hidden_size] * layers
    num_blocks = [block_size] * layers
    input_dim = 1000
    in_channels = 64
    model = ResNet(hidden_sizes, num_blocks, input_dim, in_channels, n_classes=1)
    model.compile(optimizer='adam', 
              loss='binary_crossentropy',
              metrics=['accuracy'])
    model.build(input_shape=(None, input_dim, 1))
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "res_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  320
#
#  batch_normalization (BatchN  multiple                 256
#  ormalization)
#
#  sequential_12 (Sequential)  (None, 250, 50)           168936
#
#  global_average_pooling1d_12  multiple                 0
#   (GlobalAveragePooling1D)
#
#  dense_24 (Dense)            multiple                  51
#
# =================================================================
# Total params: 169,563
# Trainable params: 167,935
# Non-trainable params: 1,628
# _________________________________________________________________

# %%
import pickle

# %%
history = model.fit(X_train.reshape(-1, 1000, 1),y_train[:,2],epochs = 30, validation_data = (X_test.reshape(-1,1000,1),y_test[:,2]))
filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/senet_individual_2.pkl'

pickle.dump(model, open(filepath, 'wb'))
# Out:
# Epoch 1/30
# 4219/4219 [==============================] - 204s 43ms/step - loss: 0.5122 - accuracy: 0.7452 - val_loss: 0.5234 - val_accuracy: 0.7376
# Epoch 2/30
# 4219/4219 [==============================] - 184s 44ms/step - loss: 0.4483 - accuracy: 0.7888 - val_loss: 0.4743 - val_accuracy: 0.7778
# Epoch 3/30
# 4219/4219 [==============================] - 188s 45ms/step - loss: 0.4252 - accuracy: 0.8040 - val_loss: 0.4096 - val_accuracy: 0.8122
# Epoch 4/30
# 4219/4219 [==============================] - 186s 44ms/step - loss: 0.4115 - accuracy: 0.8121 - val_loss: 0.5714 - val_accuracy: 0.6900
# Epoch 5/30
# 4219/4219 [==============================] - 188s 45ms/step - loss: 0.4007 - accuracy: 0.8182 - val_loss: 0.4941 - val_accuracy: 0.7568
# Epoch 6/30
# 4219/4219 [==============================] - 190s 45ms/step - loss: 0.3926 - accuracy: 0.8225 - val_loss: 0.4445 - val_accuracy: 0.7869
# Epoch 7/30
# 4219/4219 [==============================] - 186s 44ms/step - loss: 0.3862 - accuracy: 0.8274 - val_loss: 0.4680 - val_accuracy: 0.7693
# Epoch 8/30
# 4219/4219 [==============================] - 182s 43ms/step - loss: 0.3802 - accuracy: 0.8310 - val_loss: 0.5199 - val_accuracy: 0.7464
# Epoch 9/30
# 4219/4219 [==============================] - 190s 45ms/step - loss: 0.3730 - accuracy: 0.8347 - val_loss: 0.4057 - val_accuracy: 0.8173
# Epoch 29/30
# 4219/4219 [==============================] - 191s 45ms/step - loss: 0.2621 - accuracy: 0.8931 - val_loss: 0.4299 - val_accuracy: 0.8352
# Epoch 30/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.2567 - accuracy: 0.8966 - val_loss: 0.5337 - val_accuracy: 0.8130

# %%
np.save('/content/drive/MyDrive/data sem thesis abhishek/normalised_data/senet_individual_history_2.npy',history.history)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import pickle

# %%
model = create_model()

# %%
history = model.fit(X_train.reshape(-1, 1000, 1),y_train[:,3],epochs = 30, validation_data = (X_test.reshape(-1,1000,1),y_test[:,3]))
filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/senet_individual_3.pkl'
# Out:
# Epoch 1/30
# 4219/4219 [==============================] - 201s 42ms/step - loss: 0.5258 - accuracy: 0.7365 - val_loss: 0.5053 - val_accuracy: 0.7493
# Epoch 2/30
# 4219/4219 [==============================] - 193s 46ms/step - loss: 0.4557 - accuracy: 0.7857 - val_loss: 0.5189 - val_accuracy: 0.7568
# Epoch 3/30
# 4219/4219 [==============================] - 177s 42ms/step - loss: 0.4368 - accuracy: 0.7970 - val_loss: 0.4582 - val_accuracy: 0.7817
# Epoch 4/30
# 4219/4219 [==============================] - 184s 44ms/step - loss: 0.4263 - accuracy: 0.8032 - val_loss: 0.4548 - val_accuracy: 0.7862
# Epoch 5/30
# 4219/4219 [==============================] - 182s 43ms/step - loss: 0.4180 - accuracy: 0.8094 - val_loss: 0.4710 - val_accuracy: 0.7735
# Epoch 6/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.4106 - accuracy: 0.8131 - val_loss: 0.4270 - val_accuracy: 0.7996
# Epoch 7/30
# 4219/4219 [==============================] - 185s 44ms/step - loss: 0.4053 - accuracy: 0.8165 - val_loss: 0.4316 - val_accuracy: 0.7993
# Epoch 8/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.3979 - accuracy: 0.8205 - val_loss: 0.4191 - val_accuracy: 0.8082
# Epoch 9/30
# 4219/4219 [==============================] - 184s 44ms/step - loss: 0.3926 - accuracy: 0.8241 - val_loss: 0.6314 - val_accuracy: 0.6874
# Epoch 10/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.3863 - accuracy: 0.8282 - val_loss: 0.4478 - val_accuracy: 0.7884
# Epoch 11/30
# 4219/4219 [==============================] - 184s 44ms/step - loss: 0.3802 - accuracy: 0.8320 - val_loss: 0.4665 - val_accuracy: 0.7940
# Epoch 12/30
# 4219/4219 [==============================] - 184s 44ms/step - loss: 0.3753 - accuracy: 0.8338 - val_loss: 0.6325 - val_accuracy: 0.6629
# Epoch 13/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.3687 - accuracy: 0.8380 - val_loss: 0.4739 - val_accuracy: 0.7753
# Epoch 14/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.3635 - accuracy: 0.8400 - val_loss: 0.3868 - val_accuracy: 0.8262
# Epoch 15/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.3582 - accuracy: 0.8443 - val_loss: 0.5875 - val_accuracy: 0.6909
# Epoch 16/30
# 4219/4219 [==============================] - 175s 42ms/step - loss: 0.3518 - accuracy: 0.8478 - val_loss: 0.3882 - val_accuracy: 0.8266
# Epoch 17/30
# 4219/4219 [==============================] - 182s 43ms/step - loss: 0.3464 - accuracy: 0.8500 - val_loss: 0.4448 - val_accuracy: 0.8076
# Epoch 18/30
# 4219/4219 [==============================] - 175s 41ms/step - loss: 0.3390 - accuracy: 0.8541 - val_loss: 0.5559 - val_accuracy: 0.7358
# Epoch 19/30
# 4219/4219 [==============================] - 181s 43ms/step - loss: 0.3351 - accuracy: 0.8563 - val_loss: 0.3952 - val_accuracy: 0.8234
# Epoch 20/30
# 4219/4219 [==============================] - 181s 43ms/step - loss: 0.3289 - accuracy: 0.8598 - val_loss: 0.4220 - val_accuracy: 0.8142
# Epoch 21/30
# 4219/4219 [==============================] - 179s 42ms/step - loss: 0.3230 - accuracy: 0.8634 - val_loss: 0.4319 - val_accuracy: 0.8168
# Epoch 22/30
# 4219/4219 [==============================] - 182s 43ms/step - loss: 0.3181 - accuracy: 0.8651 - val_loss: 0.3995 - val_accuracy: 0.8238
# Epoch 23/30
# 4219/4219 [==============================] - 179s 42ms/step - loss: 0.3114 - accuracy: 0.8685 - val_loss: 0.6077 - val_accuracy: 0.7547
# Epoch 24/30
# 4219/4219 [==============================] - 182s 43ms/step - loss: 0.3045 - accuracy: 0.8732 - val_loss: 0.4590 - val_accuracy: 0.7870
# Epoch 25/30
# 4219/4219 [==============================] - 173s 41ms/step - loss: 0.2989 - accuracy: 0.8760 - val_loss: 0.4963 - val_accuracy: 0.7614
# Epoch 26/30
# 4219/4219 [==============================] - 182s 43ms/step - loss: 0.2928 - accuracy: 0.8784 - val_loss: 0.6161 - val_accuracy: 0.7622
# Epoch 27/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.2877 - accuracy: 0.8816 - val_loss: 0.4318 - val_accuracy: 0.8190
# Epoch 28/30
# 4219/4219 [==============================] - 183s 43ms/step - loss: 0.2802 - accuracy: 0.8861 - val_loss: 0.4207 - val_accuracy: 0.8256
# Epoch 29/30
# 4219/4219 [==============================] - 187s 44ms/step - loss: 0.2756 - accuracy: 0.8878 - val_loss: 0.4324 - val_accuracy: 0.8207
# Epoch 30/30
# 4219/4219 [==============================] - 178s 42ms/step - loss: 0.2687 - accuracy: 0.8912 - val_loss: 1.3285 - val_accuracy: 0.6778
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9226c08a1653> in <cell line: 4>()
#       2 filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/senet_individual_3.pkl'
#       3
# ----> 4 pickle.dump(model, open(filepath, 'wb'))
#
# NameError: name 'pickle' is not defined

# %%
pickle.dump(model, open(filepath, 'wb'))

# %%
import matplotlib.pyplot as plt

# %%
np.save('/content/drive/MyDrive/data sem thesis abhishek/normalised_data/senet_individual_history_3.npy',history.history)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
