# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/X_datagen_allcomb_foreign_class_fixed_more_latest_normalised.npy")
X.shape
# Out:
# (180000, 1000)

# %%
y = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/y_datagen_allcomb_foreign_hotencoding_fixed_more_latest_normalised.npy")
y.shape
# Out:
# (180000, 5)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,shuffle = True, random_state = 34)

# %%
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, Flatten, Dense

# %%
class ResidualBlock(tf.keras.layers.Layer):
    def __init__(self, in_channels, out_channels, stride=1, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()

        # Layers
        self.conv1 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=stride, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.dropout = tf.keras.layers.Dropout(dropout_rate)

        self.shortcut = tf.keras.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = tf.keras.Sequential([
                tf.keras.layers.Conv1D(out_channels, kernel_size=1,
                                        strides=stride, use_bias=False),
                tf.keras.layers.BatchNormalization()
            ])

    def call(self, x):
        out = tf.nn.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.dropout(out)
        out += self.shortcut(x)
        out = tf.nn.relu(out)
        return out


class ResNet(tf.keras.Model):
    def __init__(self, hidden_sizes, num_blocks, input_dim=1000,
                 in_channels=64, n_classes=5, dropout_rate=0.2):
        super(ResNet, self).__init__()
        assert len(num_blocks) == len(hidden_sizes)
        self.input_dim = input_dim
        self.in_channels = in_channels
        self.n_classes = n_classes
        self.dropout_rate = dropout_rate
        
        self.conv1 = tf.keras.layers.Conv1D(in_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        
        # Flexible number of residual encoding layers
        layers = []
        strides = [1] + [2] * (len(hidden_sizes) - 1)
        for idx, hidden_size in enumerate(hidden_sizes):
            layers.append(self._make_layer(hidden_size, num_blocks[idx],
                                            stride=strides[idx]))
        self.encoder = tf.keras.Sequential(layers)

        self.global_pooling = tf.keras.layers.GlobalAveragePooling1D()
        self.z_dim = self._get_encoding_size()
        self.linear = tf.keras.layers.Dense(n_classes, activation='sigmoid')


    def encode(self, x):
        x = tf.nn.relu(self.bn1(self.conv1(x)))
        x = self.encoder(x)
        x = self.global_pooling(x)
        return x

    def call(self, x):
        z = self.encode(x)
        logits = self.linear(z)
        return logits


    def _make_layer(self, out_channels, num_blocks, stride=1):
        strides = [stride] + [1] * (num_blocks - 1)
        blocks = []
        for stride in strides:
            blocks.append(ResidualBlock(self.in_channels, out_channels,
                                            stride=stride, dropout_rate=self.dropout_rate))
            self.in_channels = out_channels
        return tf.keras.Sequential(blocks)

    def _get_encoding_size(self):
        """
        Returns the dimension of the encoded input.
        """
        temp = tf.random.normal((1, self.input_dim, 1))
        z = self.encode(temp)
        z_dim = z.shape[1]
        return z_dim

# %%
def create_model():
    layers = 3
    hidden_size = 50
    block_size = 2
    hidden_sizes = [hidden_size] * layers
    num_blocks = [block_size] * layers
    input_dim = 1000
    in_channels = 64
    model = ResNet(hidden_sizes, num_blocks, input_dim, in_channels, n_classes=4)
    model.compile(optimizer='adam', 
              loss=4*['binary_crossentropy'],
              metrics=['accuracy'])
    model.build(input_shape=(None, input_dim, 1))
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "res_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  320
#
#  batch_normalization (BatchN  multiple                 256
#  ormalization)
#
#  sequential_12 (Sequential)  (None, 250, 50)           164700
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dense (Dense)               multiple                  204
#
# =================================================================
# Total params: 165,480
# Trainable params: 163,852
# Non-trainable params: 1,628
# _________________________________________________________________

# %%
import pickle

# %%
history = model.fit(X_train.reshape(-1, 1000, 1),y_train[:,:4],epochs = 30, validation_data = (X_test.reshape(-1,1000,1),y_test[:,:4]))
filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/Resnet_combined_30.pkl'

pickle.dump(model, open(filepath, 'wb'))
# Out:
# Epoch 1/30
# 4219/4219 [==============================] - 151s 32ms/step - loss: 0.4789 - accuracy: 0.5809 - val_loss: 0.7198 - val_accuracy: 0.5285
# Epoch 2/30
# 4219/4219 [==============================] - 138s 33ms/step - loss: 0.4114 - accuracy: 0.6172 - val_loss: 0.4926 - val_accuracy: 0.5274
# Epoch 3/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3910 - accuracy: 0.6225 - val_loss: 0.4121 - val_accuracy: 0.6290
# Epoch 4/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3807 - accuracy: 0.6230 - val_loss: 0.4408 - val_accuracy: 0.5949
# Epoch 5/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3742 - accuracy: 0.6254 - val_loss: 0.5166 - val_accuracy: 0.6421
# Epoch 6/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3692 - accuracy: 0.6247 - val_loss: 0.3980 - val_accuracy: 0.5417
# Epoch 7/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3648 - accuracy: 0.6277 - val_loss: 0.4024 - val_accuracy: 0.6495
# Epoch 8/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3617 - accuracy: 0.6263 - val_loss: 0.3673 - val_accuracy: 0.6407
# Epoch 9/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3580 - accuracy: 0.6285 - val_loss: 0.4941 - val_accuracy: 0.6490
# Epoch 10/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3553 - accuracy: 0.6290 - val_loss: 0.3863 - val_accuracy: 0.5402
# Epoch 11/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3537 - accuracy: 0.6268 - val_loss: 0.4244 - val_accuracy: 0.6556
# Epoch 12/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3514 - accuracy: 0.6275 - val_loss: 0.3992 - val_accuracy: 0.5554
# Epoch 13/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3493 - accuracy: 0.6283 - val_loss: 0.4201 - val_accuracy: 0.5758
# Epoch 14/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3477 - accuracy: 0.6290 - val_loss: 0.4427 - val_accuracy: 0.5376
# Epoch 15/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3456 - accuracy: 0.6282 - val_loss: 0.4079 - val_accuracy: 0.5759
# Epoch 16/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3444 - accuracy: 0.6288 - val_loss: 0.4286 - val_accuracy: 0.5536
# Epoch 17/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3432 - accuracy: 0.6301 - val_loss: 0.3741 - val_accuracy: 0.6345
# Epoch 18/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3408 - accuracy: 0.6287 - val_loss: 0.3425 - val_accuracy: 0.6460
# Epoch 19/30
# 4219/4219 [==============================] - 134s 32ms/step - loss: 0.3400 - accuracy: 0.6292 - val_loss: 0.3487 - val_accuracy: 0.6317
# Epoch 20/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3384 - accuracy: 0.6277 - val_loss: 0.3604 - val_accuracy: 0.6253
# Epoch 21/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3374 - accuracy: 0.6287 - val_loss: 0.4103 - val_accuracy: 0.5655
# Epoch 22/30
# 4219/4219 [==============================] - 137s 33ms/step - loss: 0.3358 - accuracy: 0.6293 - val_loss: 0.3861 - val_accuracy: 0.6490
# Epoch 23/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3354 - accuracy: 0.6278 - val_loss: 0.4071 - val_accuracy: 0.6054
# Epoch 24/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3335 - accuracy: 0.6269 - val_loss: 0.4351 - val_accuracy: 0.6000
# Epoch 25/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3323 - accuracy: 0.6282 - val_loss: 0.3670 - val_accuracy: 0.5972
# Epoch 26/30
# 4219/4219 [==============================] - 135s 32ms/step - loss: 0.3317 - accuracy: 0.6291 - val_loss: 0.3486 - val_accuracy: 0.6621
# Epoch 27/30
# 4219/4219 [==============================] - 134s 32ms/step - loss: 0.3307 - accuracy: 0.6281 - val_loss: 0.3722 - val_accuracy: 0.6282
# Epoch 28/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3293 - accuracy: 0.6295 - val_loss: 0.3508 - val_accuracy: 0.6337
# Epoch 29/30
# 4219/4219 [==============================] - 136s 32ms/step - loss: 0.3283 - accuracy: 0.6273 - val_loss: 0.3566 - val_accuracy: 0.6252
# Epoch 30/30
# 4219/4219 [==============================] - 134s 32ms/step - loss: 0.3272 - accuracy: 0.6271 - val_loss: 0.3345 - val_accuracy: 0.6184

# %%
np.save('/content/drive/MyDrive/data sem thesis abhishek/normalised_data/Resnet_combined_history_30.npy',history.history)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
