# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/X_datagen_allcomb_foreign_class_fixed_more_latest_normalised.npy")
X.shape
# Out:
# (180000, 1000)

# %%
y = np.load("/content/drive/MyDrive/data sem thesis abhishek/normalised_data/y_datagen_allcomb_foreign_hotencoding_fixed_more_latest_normalised.npy")
y.shape
# Out:
# (180000, 5)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,shuffle = True, random_state = 34)

# %%
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, Flatten, Dense

# %%
class ResidualBlock(tf.keras.layers.Layer):
    def __init__(self, in_channels, out_channels, stride=1, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()

        # Layers
        self.conv1 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=stride, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv1D(out_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            dilation_rate=1, use_bias=False)
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.dropout = tf.keras.layers.Dropout(dropout_rate)

        self.shortcut = tf.keras.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = tf.keras.Sequential([
                tf.keras.layers.Conv1D(out_channels, kernel_size=1,
                                        strides=stride, use_bias=False),
                tf.keras.layers.BatchNormalization()
            ])

    def call(self, x):
        out = tf.nn.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.dropout(out)
        out += self.shortcut(x)
        out = tf.nn.relu(out)
        return out


class ResNet(tf.keras.Model):
    def __init__(self, hidden_sizes, num_blocks, input_dim=1000,
                 in_channels=64, n_classes=5, dropout_rate=0.2):
        super(ResNet, self).__init__()
        assert len(num_blocks) == len(hidden_sizes)
        self.input_dim = input_dim
        self.in_channels = in_channels
        self.n_classes = n_classes
        self.dropout_rate = dropout_rate
        
        self.conv1 = tf.keras.layers.Conv1D(in_channels, kernel_size=5,
                                            strides=1, padding='same',
                                            use_bias=False)
        self.bn1 = tf.keras.layers.BatchNormalization()
        
        # Flexible number of residual encoding layers
        layers = []
        strides = [1] + [2] * (len(hidden_sizes) - 1)
        for idx, hidden_size in enumerate(hidden_sizes):
            layers.append(self._make_layer(hidden_size, num_blocks[idx],
                                            stride=strides[idx]))
        self.encoder = tf.keras.Sequential(layers)

        self.global_pooling = tf.keras.layers.GlobalAveragePooling1D()
        self.z_dim = self._get_encoding_size()
        self.linear = tf.keras.layers.Dense(n_classes, activation='sigmoid')


    def encode(self, x):
        x = tf.nn.relu(self.bn1(self.conv1(x)))
        x = self.encoder(x)
        x = self.global_pooling(x)
        return x

    def call(self, x):
        z = self.encode(x)
        logits = self.linear(z)
        return logits


    def _make_layer(self, out_channels, num_blocks, stride=1):
        strides = [stride] + [1] * (num_blocks - 1)
        blocks = []
        for stride in strides:
            blocks.append(ResidualBlock(self.in_channels, out_channels,
                                            stride=stride, dropout_rate=self.dropout_rate))
            self.in_channels = out_channels
        return tf.keras.Sequential(blocks)

    def _get_encoding_size(self):
        """
        Returns the dimension of the encoded input.
        """
        temp = tf.random.normal((1, self.input_dim, 1))
        z = self.encode(temp)
        z_dim = z.shape[1]
        return z_dim

# %%
def create_model():
    layers = 3
    hidden_size = 50
    block_size = 2
    hidden_sizes = [hidden_size] * layers
    num_blocks = [block_size] * layers
    input_dim = 1000
    in_channels = 64
    model = ResNet(hidden_sizes, num_blocks, input_dim, in_channels, n_classes=1)
    model.compile(optimizer='adam', 
              loss=['binary_crossentropy'],
              metrics=['accuracy'])
    model.build(input_shape=(None, input_dim, 1))
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "res_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             multiple                  320
#
#  batch_normalization (BatchN  multiple                 256
#  ormalization)
#
#  sequential_12 (Sequential)  (None, 250, 50)           164700
#
#  global_average_pooling1d (G  multiple                 0
#  lobalAveragePooling1D)
#
#  dense (Dense)               multiple                  51
#
# =================================================================
# Total params: 165,327
# Trainable params: 163,699
# Non-trainable params: 1,628
# _________________________________________________________________

# %%
import pickle

# %%
history = model.fit(X_train.reshape(-1, 1000, 1),y_train[:,2],epochs = 30, validation_data = (X_test.reshape(-1,1000,1),y_test[:,2]))
filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/Resnet_individual_2.pkl'

pickle.dump(model, open(filepath, 'wb'))
# Out:
# Epoch 1/30
# 4219/4219 [==============================] - 180s 37ms/step - loss: 0.5476 - accuracy: 0.7199 - val_loss: 0.5605 - val_accuracy: 0.7188
# Epoch 2/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.4915 - accuracy: 0.7626 - val_loss: 0.4835 - val_accuracy: 0.7714
# Epoch 3/30
# 4219/4219 [==============================] - 138s 33ms/step - loss: 0.4591 - accuracy: 0.7848 - val_loss: 0.4673 - val_accuracy: 0.7831
# Epoch 4/30
# 4219/4219 [==============================] - 138s 33ms/step - loss: 0.4439 - accuracy: 0.7934 - val_loss: 0.6301 - val_accuracy: 0.6942
# Epoch 5/30
# 4219/4219 [==============================] - 138s 33ms/step - loss: 0.4338 - accuracy: 0.8008 - val_loss: 0.5804 - val_accuracy: 0.7276
# Epoch 6/30
# 4219/4219 [==============================] - 137s 33ms/step - loss: 0.4261 - accuracy: 0.8047 - val_loss: 0.7882 - val_accuracy: 0.5982
# Epoch 7/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.4207 - accuracy: 0.8077 - val_loss: 0.4322 - val_accuracy: 0.8106
# Epoch 8/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.4154 - accuracy: 0.8116 - val_loss: 0.4467 - val_accuracy: 0.8062
# Epoch 9/30
# 4219/4219 [==============================] - 137s 33ms/step - loss: 0.4115 - accuracy: 0.8135 - val_loss: 0.4052 - val_accuracy: 0.8184
# Epoch 10/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.4073 - accuracy: 0.8161 - val_loss: 0.6441 - val_accuracy: 0.6994
# Epoch 11/30
# 4219/4219 [==============================] - 137s 33ms/step - loss: 0.4023 - accuracy: 0.8186 - val_loss: 0.4526 - val_accuracy: 0.8025
# Epoch 12/30
# 4219/4219 [==============================] - 137s 33ms/step - loss: 0.3988 - accuracy: 0.8209 - val_loss: 0.6120 - val_accuracy: 0.7168
# Epoch 13/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3951 - accuracy: 0.8236 - val_loss: 0.5383 - val_accuracy: 0.7473
# Epoch 14/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3924 - accuracy: 0.8237 - val_loss: 0.3934 - val_accuracy: 0.8307
# Epoch 15/30
# 4219/4219 [==============================] - 147s 35ms/step - loss: 0.3875 - accuracy: 0.8264 - val_loss: 0.4799 - val_accuracy: 0.7664
# Epoch 16/30
# 4219/4219 [==============================] - 137s 33ms/step - loss: 0.3840 - accuracy: 0.8294 - val_loss: 0.4426 - val_accuracy: 0.7796
# Epoch 17/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3802 - accuracy: 0.8319 - val_loss: 0.3977 - val_accuracy: 0.8326
# Epoch 18/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3773 - accuracy: 0.8328 - val_loss: 0.3973 - val_accuracy: 0.8219
# Epoch 19/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3740 - accuracy: 0.8346 - val_loss: 0.4442 - val_accuracy: 0.8140
# Epoch 20/30
# 4219/4219 [==============================] - 137s 32ms/step - loss: 0.3695 - accuracy: 0.8364 - val_loss: 0.6198 - val_accuracy: 0.7083
# Epoch 21/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3680 - accuracy: 0.8375 - val_loss: 0.4168 - val_accuracy: 0.8003
# Epoch 22/30
# 4219/4219 [==============================] - 146s 35ms/step - loss: 0.3650 - accuracy: 0.8395 - val_loss: 0.5466 - val_accuracy: 0.7235
# Epoch 23/30
# 4219/4219 [==============================] - 139s 33ms/step - loss: 0.3612 - accuracy: 0.8409 - val_loss: 0.4062 - val_accuracy: 0.8310
# Epoch 24/30
# 4219/4219 [==============================] - 153s 36ms/step - loss: 0.3580 - accuracy: 0.8429 - val_loss: 0.4171 - val_accuracy: 0.8311
# Epoch 25/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.3546 - accuracy: 0.8438 - val_loss: 0.4537 - val_accuracy: 0.7960
# Epoch 26/30
# 4219/4219 [==============================] - 155s 37ms/step - loss: 0.3518 - accuracy: 0.8462 - val_loss: 0.5945 - val_accuracy: 0.7220
# Epoch 27/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.3489 - accuracy: 0.8479 - val_loss: 0.3959 - val_accuracy: 0.8317
# Epoch 28/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.3455 - accuracy: 0.8491 - val_loss: 0.4205 - val_accuracy: 0.8294
# Epoch 29/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3430 - accuracy: 0.8499 - val_loss: 0.4483 - val_accuracy: 0.8290
# Epoch 30/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3409 - accuracy: 0.8519 - val_loss: 0.4066 - val_accuracy: 0.8259

# %%
np.save('/content/drive/MyDrive/data sem thesis abhishek/normalised_data/Resnet_individual_history_2.npy',history.history)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = create_model()

# %%
history = model.fit(X_train.reshape(-1, 1000, 1),y_train[:,3],epochs = 30, validation_data = (X_test.reshape(-1,1000,1),y_test[:,3]))
filepath = '/content/drive/MyDrive/data sem thesis abhishek/New_models/Resnet_individual_3.pkl'

pickle.dump(model, open(filepath, 'wb'))
# Out:
# Epoch 1/30
# 4219/4219 [==============================] - 156s 34ms/step - loss: 0.5578 - accuracy: 0.7151 - val_loss: 0.5539 - val_accuracy: 0.7124
# Epoch 2/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.4994 - accuracy: 0.7584 - val_loss: 0.5170 - val_accuracy: 0.7458
# Epoch 3/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.4784 - accuracy: 0.7731 - val_loss: 0.5574 - val_accuracy: 0.7514
# Epoch 4/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.4672 - accuracy: 0.7808 - val_loss: 0.9154 - val_accuracy: 0.6103
# Epoch 5/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.4580 - accuracy: 0.7861 - val_loss: 0.5844 - val_accuracy: 0.7177
# Epoch 6/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.4514 - accuracy: 0.7906 - val_loss: 0.4489 - val_accuracy: 0.7939
# Epoch 7/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.4468 - accuracy: 0.7924 - val_loss: 0.7464 - val_accuracy: 0.6123
# Epoch 8/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.4406 - accuracy: 0.7971 - val_loss: 0.4680 - val_accuracy: 0.7897
# Epoch 9/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.4360 - accuracy: 0.7997 - val_loss: 0.7268 - val_accuracy: 0.6565
# Epoch 10/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.4324 - accuracy: 0.8016 - val_loss: 0.4625 - val_accuracy: 0.7877
# Epoch 11/30
# 4219/4219 [==============================] - 152s 36ms/step - loss: 0.4270 - accuracy: 0.8048 - val_loss: 0.5128 - val_accuracy: 0.7718
# Epoch 12/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.4229 - accuracy: 0.8072 - val_loss: 0.4390 - val_accuracy: 0.8032
# Epoch 13/30
# 4219/4219 [==============================] - 150s 36ms/step - loss: 0.4188 - accuracy: 0.8103 - val_loss: 0.4952 - val_accuracy: 0.7771
# Epoch 14/30
# 4219/4219 [==============================] - 150s 36ms/step - loss: 0.4151 - accuracy: 0.8115 - val_loss: 0.5909 - val_accuracy: 0.7384
# Epoch 15/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.4113 - accuracy: 0.8135 - val_loss: 0.4225 - val_accuracy: 0.8067
# Epoch 16/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.4062 - accuracy: 0.8173 - val_loss: 0.4273 - val_accuracy: 0.8001
# Epoch 17/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.4026 - accuracy: 0.8195 - val_loss: 0.5699 - val_accuracy: 0.7499
# Epoch 18/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.3994 - accuracy: 0.8207 - val_loss: 0.4791 - val_accuracy: 0.7691
# Epoch 19/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.3962 - accuracy: 0.8224 - val_loss: 0.4484 - val_accuracy: 0.7960
# Epoch 20/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3924 - accuracy: 0.8233 - val_loss: 0.5129 - val_accuracy: 0.7579
# Epoch 21/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.3884 - accuracy: 0.8268 - val_loss: 0.4358 - val_accuracy: 0.8136
# Epoch 22/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.3844 - accuracy: 0.8278 - val_loss: 0.4538 - val_accuracy: 0.8006
# Epoch 23/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.3812 - accuracy: 0.8303 - val_loss: 0.5567 - val_accuracy: 0.7268
# Epoch 24/30
# 4219/4219 [==============================] - 150s 36ms/step - loss: 0.3789 - accuracy: 0.8316 - val_loss: 0.4782 - val_accuracy: 0.8052
# Epoch 25/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3748 - accuracy: 0.8333 - val_loss: 0.6229 - val_accuracy: 0.7503
# Epoch 26/30
# 4219/4219 [==============================] - 151s 36ms/step - loss: 0.3721 - accuracy: 0.8352 - val_loss: 0.5058 - val_accuracy: 0.7640
# Epoch 27/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.3688 - accuracy: 0.8367 - val_loss: 0.4292 - val_accuracy: 0.8070
# Epoch 28/30
# 4219/4219 [==============================] - 140s 33ms/step - loss: 0.3663 - accuracy: 0.8377 - val_loss: 0.6248 - val_accuracy: 0.7453
# Epoch 29/30
# 4219/4219 [==============================] - 141s 33ms/step - loss: 0.3623 - accuracy: 0.8410 - val_loss: 0.4195 - val_accuracy: 0.8207
# Epoch 30/30
# 4219/4219 [==============================] - 142s 34ms/step - loss: 0.3602 - accuracy: 0.8416 - val_loss: 0.4336 - val_accuracy: 0.8156

# %%
np.save('/content/drive/MyDrive/data sem thesis abhishek/normalised_data/Resnet_individual_history_3.npy',history.history)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
